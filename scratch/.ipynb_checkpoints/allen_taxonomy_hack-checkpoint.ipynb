# %%
import json
f = open('dend.json', 'r')
j = json.loads(f.read())
j
# Out:
# {'node_attributes': [{'members': 75,
#    'midpoint': 57.5288,
#    'height': 0.9146,
#    'label': '',
#    'cell_set_accession': 'CS201908210_76',
#    'original_label': 'n1',
#    'cell_set_label': 'All cells',
#    'cell_set_preferred_alias': '',
#    'cell_set_aligned_alias': '',
#    'cell_set_additional_aliases': '',
#    'cell_set_structure': 'neocortex',
#    'cell_set_alias_assignee': 'Trygve Bakken||',
#    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#    'cell_set_ontology_tag': 'UBERON:0001950',
#    'taxonomy_id': 'CCN201908210',
#    '_row': 'n1'}],
#  'children': [{'node_attributes': [{'members': 69,
#      'midpoint': 42.0889,
#      'height': 0.5566,
#      'label': 'Neuronal',
#      'cell_set_accession': 'CS201908210_77',
#      'original_label': 'n2',
#      'cell_set_label': 'MTG 001-069',
#      'cell_set_preferred_alias': 'Neuronal',
#      'cell_set_aligned_alias': '',
#      'cell_set_additional_aliases': '',
#      'cell_set_structure': 'neocortex',
#      'cell_set_alias_assignee': 'Trygve Bakken||',
#      'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#      'cell_set_ontology_tag': 'UBERON:0001950',
#      'taxonomy_id': 'CCN201908210',
#      '_row': 'n2'}],
#    'children': [{'node_attributes': [{'members': 45,
#        'midpoint': 23.2148,
#        'height': 0.4148,
#        'label': 'Inhibitory',
#        'cell_set_accession': 'CS201908210_78',
#        'original_label': 'n3',
#        'cell_set_label': 'MTG 001-045',
#        'cell_set_preferred_alias': 'Inhibitory',
#        'cell_set_aligned_alias': 'GABAergic',
#        'cell_set_additional_aliases': '',
#        'cell_set_structure': 'neocortex',
#        'cell_set_alias_assignee': 'Trygve Bakken||',
#        'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#        'cell_set_ontology_tag': 'UBERON:0001950',
#        'taxonomy_id': 'CCN201908210',
#        '_row': 'n3'}],
#      'children': [{'node_attributes': [{'members': 27,
#          'midpoint': 8.4297,
#          'height': 0.3449,
#          'label': 'ADARB2 (CGE)',
#          'cell_set_accession': 'CS201908210_79',
#          'original_label': 'n4',
#          'cell_set_label': 'MTG 001-027',
#          'cell_set_preferred_alias': 'ADARB2 (CGE)',
#          'cell_set_aligned_alias': 'CGE/PoA',
#          'cell_set_additional_aliases': '',
#          'cell_set_structure': 'neocortex',
#          'cell_set_alias_assignee': 'Trygve Bakken||',
#          'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#          'cell_set_ontology_tag': 'UBERON:0001950',
#          'taxonomy_id': 'CCN201908210',
#          '_row': 'n4'}],
#        'children': [{'node_attributes': [{'members': 6,
#            'midpoint': 1.8125,
#            'height': 0.2938,
#            'label': 'LAMP5/PAX6',
#            'cell_set_accession': 'CS201908210_80',
#            'original_label': 'n5',
#            'cell_set_label': 'MTG 001-006',
#            'cell_set_preferred_alias': 'LAMP5/PAX6',
#            'cell_set_aligned_alias': '',
#            'cell_set_additional_aliases': '',
#            'cell_set_structure': 'neocortex',
#            'cell_set_alias_assignee': 'Trygve Bakken||',
#            'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#            'cell_set_ontology_tag': 'UBERON:0001950',
#            'taxonomy_id': 'CCN201908210',
#            '_row': 'n5'}],
#          'children': [{'node_attributes': [{'members': 2,
#              'midpoint': 0.5,
#              'height': 0.1516,
#              'label': '',
#              'cell_set_accession': 'CS201908210_81',
#              'original_label': 'n6',
#              'cell_set_label': 'MTG 001-002',
#              'cell_set_preferred_alias': '',
#              'cell_set_aligned_alias': 'Pax6',
#              'cell_set_additional_aliases': '',
#              'cell_set_structure': 'neocortex',
#              'cell_set_alias_assignee': 'Trygve Bakken||',
#              'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#              'cell_set_ontology_tag': 'UBERON:0001950',
#              'taxonomy_id': 'CCN201908210',
#              '_row': 'n6'}],
#            'children': [{'leaf_attributes': [{'label': 'Inh L1-2 PAX6 CDH12',
#                'members': 1,
#                'height': 0,
#                'leaf': True,
#                'nodePar.pch': 19,
#                'nodePar.cex': 2,
#                'nodePar.lab.cex': 0.25,
#                'nodePar.lab.col': '#DDACC9',
#                'nodePar.col': '#DDACC9',
#                'cell_set_accession': 'CS201908210_1',
#                'original_label': 'Inh L1-2 PAX6 CDH12',
#                'cell_set_label': 'MTG 001',
#                'cell_set_preferred_alias': 'Inh L1-2 PAX6 CDH12',
#                'cell_set_aligned_alias': '',
#                'cell_set_additional_aliases': '',
#                'cell_set_structure': 'neocortex',
#                'cell_set_alias_assignee': 'Trygve Bakken||',
#                'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                'cell_set_ontology_tag': 'UBERON:0001950',
#                'taxonomy_id': 'CCN201908210',
#                '_row': 'Inh L1-2 PAX6 CDH12'}]},
#             {'leaf_attributes': [{'label': 'Inh L1-2 PAX6 TNFAIP8L3',
#                'members': 1,
#                'height': 0,
#                'leaf': True,
#                'nodePar.pch': 19,
#                'nodePar.cex': 2,
#                'nodePar.lab.cex': 0.25,
#                'nodePar.lab.col': '#FF88AD',
#                'nodePar.col': '#FF88AD',
#                'cell_set_accession': 'CS201908210_2',
#                'original_label': 'Inh L1-2 PAX6 TNFAIP8L3',
#                'cell_set_label': 'MTG 002',
#                'cell_set_preferred_alias': 'Inh L1-2 PAX6 TNFAIP8L3',
#                'cell_set_aligned_alias': '',
#                'cell_set_additional_aliases': '',
#                'cell_set_structure': 'neocortex',
#                'cell_set_alias_assignee': 'Trygve Bakken||',
#                'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                'cell_set_ontology_tag': 'UBERON:0001950',
#                'taxonomy_id': 'CCN201908210',
#                '_row': 'Inh L1-2 PAX6 TNFAIP8L3'}]}]},
#           {'node_attributes': [{'members': 4,
#              'midpoint': 1.125,
#              'height': 0.1782,
#              'label': '',
#              'cell_set_accession': 'CS201908210_82',
#              'original_label': 'n7',
#              'cell_set_label': 'MTG 003-006',
#              'cell_set_preferred_alias': '',
#              'cell_set_aligned_alias': '',
#              'cell_set_additional_aliases': '',
#              'cell_set_structure': 'neocortex',
#              'cell_set_alias_assignee': 'Trygve Bakken||',
#              'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#              'cell_set_ontology_tag': 'UBERON:0001950',
#              'taxonomy_id': 'CCN201908210',
#              '_row': 'n7'}],
#            'children': [{'leaf_attributes': [{'members': 1,
#                'height': 0,
#                'label': 'Inh L1 LAMP5 NMBR',
#                'leaf': True,
#                'nodePar.pch': 19,
#                'nodePar.cex': 2,
#                'nodePar.lab.cex': 0.25,
#                'nodePar.lab.col': '#E67B73',
#                'nodePar.col': '#E67B73',
#                'cell_set_accession': 'CS201908210_3',
#                'original_label': 'Inh L1 LAMP5 NMBR',
#                'cell_set_label': 'MTG 003',
#                'cell_set_preferred_alias': 'Inh L1 LAMP5 NMBR',
#                'cell_set_aligned_alias': '',
#                'cell_set_additional_aliases': '',
#                'cell_set_structure': 'neocortex',
#                'cell_set_alias_assignee': 'Trygve Bakken||',
#                'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                'cell_set_ontology_tag': 'UBERON:0001950',
#                'taxonomy_id': 'CCN201908210',
#                '_row': 'Inh L1 LAMP5 NMBR'}]},
#             {'node_attributes': [{'members': 3,
#                'midpoint': 1.25,
#                'height': 0.1372,
#                'label': '',
#                'cell_set_accession': 'CS201908210_83',
#                'original_label': 'n8',
#                'cell_set_label': 'MTG 004-006',
#                'cell_set_preferred_alias': '',
#                'cell_set_aligned_alias': '',
#                'cell_set_additional_aliases': '',
#                'cell_set_structure': 'neocortex',
#                'cell_set_alias_assignee': 'Trygve Bakken||',
#                'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                'cell_set_ontology_tag': 'UBERON:0001950',
#                'taxonomy_id': 'CCN201908210',
#                '_row': 'n8'}],
#              'children': [{'node_attributes': [{'members': 2,
#                  'midpoint': 0.5,
#                  'height': 0.0981,
#                  'label': '',
#                  'cell_set_accession': 'CS201908210_84',
#                  'original_label': 'n9',
#                  'cell_set_label': 'MTG 004-005',
#                  'cell_set_preferred_alias': '',
#                  'cell_set_aligned_alias': '',
#                  'cell_set_additional_aliases': 'Rosehip',
#                  'cell_set_structure': 'neocortex',
#                  'cell_set_alias_assignee': 'Trygve Bakken||',
#                  'cell_set_alias_citation': '10.1038/s41586-019-1506-7||10.1038/s41593-018-0205-2',
#                  'cell_set_ontology_tag': 'UBERON:0001950',
#                  'taxonomy_id': 'CCN201908210',
#                  '_row': 'n9'}],
#                'children': [{'leaf_attributes': [{'label': 'Inh L1-4 LAMP5 LCP2',
#                    'members': 1,
#                    'height': 0,
#                    'leaf': True,
#                    'nodePar.pch': 19,
#                    'nodePar.cex': 2,
#                    'nodePar.lab.cex': 0.25,
#                    'nodePar.lab.col': '#FFA388',
#                    'nodePar.col': '#FFA388',
#                    'cell_set_accession': 'CS201908210_4',
#                    'original_label': 'Inh L1-4 LAMP5 LCP2',
#                    'cell_set_label': 'MTG 004',
#                    'cell_set_preferred_alias': 'Inh L1-4 LAMP5 LCP2',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'Inh L1-4 LAMP5 LCP2'}]},
#                 {'leaf_attributes': [{'label': 'Inh L1-2 LAMP5 DBP',
#                    'members': 1,
#                    'height': 0,
#                    'leaf': True,
#                    'nodePar.pch': 19,
#                    'nodePar.cex': 2,
#                    'nodePar.lab.cex': 0.25,
#                    'nodePar.lab.col': '#FF7466',
#                    'nodePar.col': '#FF7466',
#                    'cell_set_accession': 'CS201908210_5',
#                    'original_label': 'Inh L1-2 LAMP5 DBP',
#                    'cell_set_label': 'MTG 005',
#                    'cell_set_preferred_alias': 'Inh L1-2 LAMP5 DBP',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'Inh L1-2 LAMP5 DBP'}]}]},
#               {'leaf_attributes': [{'members': 1,
#                  'height': 0,
#                  'label': 'Inh L2-6 LAMP5 CA1',
#                  'leaf': True,
#                  'nodePar.pch': 19,
#                  'nodePar.cex': 2,
#                  'nodePar.lab.cex': 0.25,
#                  'nodePar.lab.col': '#C77963',
#                  'nodePar.col': '#C77963',
#                  'cell_set_accession': 'CS201908210_6',
#                  'original_label': 'Inh L2-6 LAMP5 CA1',
#                  'cell_set_label': 'MTG 006',
#                  'cell_set_preferred_alias': 'Inh L2-6 LAMP5 CA1',
#                  'cell_set_aligned_alias': '',
#                  'cell_set_additional_aliases': 'Lamp Lhx6',
#                  'cell_set_structure': 'neocortex',
#                  'cell_set_alias_assignee': 'Trygve Bakken||Trygve Bakken',
#                  'cell_set_alias_citation': '10.1038/s41586-019-1506-7||10.1038/s41586-019-1506-7',
#                  'cell_set_ontology_tag': 'UBERON:0001950',
#                  'taxonomy_id': 'CCN201908210',
#                  '_row': 'Inh L2-6 LAMP5 CA1'}]}]}]}]},
#         {'node_attributes': [{'members': 21,
#            'midpoint': 9.0469,
#            'height': 0.2745,
#            'label': 'VIP',
#            'cell_set_accession': 'CS201908210_85',
#            'original_label': 'n10',
#            'cell_set_label': 'MTG 007-027',
#            'cell_set_preferred_alias': 'VIP',
#            'cell_set_aligned_alias': '',
#            'cell_set_additional_aliases': '',
#            'cell_set_structure': 'neocortex',
#            'cell_set_alias_assignee': 'Trygve Bakken||',
#            'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#            'cell_set_ontology_tag': 'UBERON:0001950',
#            'taxonomy_id': 'CCN201908210',
#            '_row': 'n10'}],
#          'children': [{'node_attributes': [{'members': 8,
#              'midpoint': 4.5,
#              'height': 0.2731,
#              'label': '',
#              'cell_set_accession': 'CS201908210_86',
#              'original_label': 'n11',
#              'cell_set_label': 'MTG 007-014',
#              'cell_set_preferred_alias': '',
#              'cell_set_aligned_alias': '',
#              'cell_set_additional_aliases': '',
#              'cell_set_structure': 'neocortex',
#              'cell_set_alias_assignee': 'Trygve Bakken||',
#              'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#              'cell_set_ontology_tag': 'UBERON:0001950',
#              'taxonomy_id': 'CCN201908210',
#              '_row': 'n11'}],
#            'children': [{'node_attributes': [{'members': 6,
#                'midpoint': 2.5,
#                'height': 0.2306,
#                'label': '',
#                'cell_set_accession': 'CS201908210_87',
#                'original_label': 'n12',
#                'cell_set_label': 'MTG 007-012',
#                'cell_set_preferred_alias': '',
#                'cell_set_aligned_alias': '',
#                'cell_set_additional_aliases': '',
#                'cell_set_structure': 'neocortex',
#                'cell_set_alias_assignee': 'Trygve Bakken||',
#                'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                'cell_set_ontology_tag': 'UBERON:0001950',
#                'taxonomy_id': 'CCN201908210',
#                '_row': 'n12'}],
#              'children': [{'node_attributes': [{'members': 3,
#                  'midpoint': 1.25,
#                  'height': 0.1322,
#                  'label': '',
#                  'cell_set_accession': 'CS201908210_88',
#                  'original_label': 'n13',
#                  'cell_set_label': 'MTG 007-009',
#                  'cell_set_preferred_alias': '',
#                  'cell_set_aligned_alias': '',
#                  'cell_set_additional_aliases': '',
#                  'cell_set_structure': 'neocortex',
#                  'cell_set_alias_assignee': 'Trygve Bakken||',
#                  'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                  'cell_set_ontology_tag': 'UBERON:0001950',
#                  'taxonomy_id': 'CCN201908210',
#                  '_row': 'n13'}],
#                'children': [{'node_attributes': [{'members': 2,
#                    'midpoint': 0.5,
#                    'height': 0.0857,
#                    'label': '',
#                    'cell_set_accession': 'CS201908210_89',
#                    'original_label': 'n14',
#                    'cell_set_label': 'MTG 007-008',
#                    'cell_set_preferred_alias': '',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'n14'}],
#                  'children': [{'leaf_attributes': [{'label': 'Inh L1 SST CHRNA4',
#                      'members': 1,
#                      'height': 0,
#                      'leaf': True,
#                      'nodePar.pch': 19,
#                      'nodePar.cex': 2,
#                      'nodePar.lab.cex': 0.25,
#                      'nodePar.lab.col': '#DD6091',
#                      'nodePar.col': '#DD6091',
#                      'cell_set_accession': 'CS201908210_7',
#                      'original_label': 'Inh L1 SST CHRNA4',
#                      'cell_set_label': 'MTG 007',
#                      'cell_set_preferred_alias': 'Inh L1 SST CHRNA4',
#                      'cell_set_aligned_alias': '',
#                      'cell_set_additional_aliases': '',
#                      'cell_set_structure': 'neocortex',
#                      'cell_set_alias_assignee': 'Trygve Bakken||',
#                      'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                      'cell_set_ontology_tag': 'UBERON:0001950',
#                      'taxonomy_id': 'CCN201908210',
#                      '_row': 'Inh L1 SST CHRNA4'}]},
#                   {'leaf_attributes': [{'label': 'Inh L1-2 ADARB2 MC4R',
#                      'members': 1,
#                      'height': 0,
#                      'leaf': True,
#                      'nodePar.pch': 19,
#                      'nodePar.cex': 2,
#                      'nodePar.lab.cex': 0.25,
#                      'nodePar.lab.col': '#FF7290',
#                      'nodePar.col': '#FF7290',
#                      'cell_set_accession': 'CS201908210_8',
#                      'original_label': 'Inh L1-2 ADARB2 MC4R',
#                      'cell_set_label': 'MTG 008',
#                      'cell_set_preferred_alias': 'Inh L1-2 ADARB2 MC4R',
#                      'cell_set_aligned_alias': '',
#                      'cell_set_additional_aliases': '',
#                      'cell_set_structure': 'neocortex',
#                      'cell_set_alias_assignee': 'Trygve Bakken||',
#                      'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                      'cell_set_ontology_tag': 'UBERON:0001950',
#                      'taxonomy_id': 'CCN201908210',
#                      '_row': 'Inh L1-2 ADARB2 MC4R'}]}]},
#                 {'leaf_attributes': [{'members': 1,
#                    'height': 0,
#                    'label': 'Inh L1-2 SST BAGE2',
#                    'leaf': True,
#                    'nodePar.pch': 19,
#                    'nodePar.cex': 2,
#                    'nodePar.lab.cex': 0.25,
#                    'nodePar.lab.col': '#9440F3',
#                    'nodePar.col': '#9440F3',
#                    'cell_set_accession': 'CS201908210_9',
#                    'original_label': 'Inh L1-2 SST BAGE2',
#                    'cell_set_label': 'MTG 009',
#                    'cell_set_preferred_alias': 'Inh L1-2 SST BAGE2',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'Inh L1-2 SST BAGE2'}]}]},
#               {'node_attributes': [{'members': 3,
#                  'midpoint': 0.75,
#                  'height': 0.1859,
#                  'label': '',
#                  'cell_set_accession': 'CS201908210_90',
#                  'original_label': 'n15',
#                  'cell_set_label': 'MTG 010-012',
#                  'cell_set_preferred_alias': '',
#                  'cell_set_aligned_alias': '',
#                  'cell_set_additional_aliases': '',
#                  'cell_set_structure': 'neocortex',
#                  'cell_set_alias_assignee': 'Trygve Bakken||',
#                  'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                  'cell_set_ontology_tag': 'UBERON:0001950',
#                  'taxonomy_id': 'CCN201908210',
#                  '_row': 'n15'}],
#                'children': [{'leaf_attributes': [{'members': 1,
#                    'height': 0,
#                    'label': 'Inh L1-3 VIP SYT6',
#                    'leaf': True,
#                    'nodePar.pch': 19,
#                    'nodePar.cex': 2,
#                    'nodePar.lab.cex': 0.25,
#                    'nodePar.lab.col': '#9900B3',
#                    'nodePar.col': '#9900B3',
#                    'cell_set_accession': 'CS201908210_10',
#                    'original_label': 'Inh L1-3 VIP SYT6',
#                    'cell_set_label': 'MTG 010',
#                    'cell_set_preferred_alias': 'Inh L1-3 VIP SYT6',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'Inh L1-3 VIP SYT6'}]},
#                 {'node_attributes': [{'members': 2,
#                    'midpoint': 0.5,
#                    'height': 0.1516,
#                    'label': '',
#                    'cell_set_accession': 'CS201908210_91',
#                    'original_label': 'n16',
#                    'cell_set_label': 'MTG 011-012',
#                    'cell_set_preferred_alias': '',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'n16'}],
#                  'children': [{'leaf_attributes': [{'label': 'Inh L1-2 VIP TSPAN12',
#                      'members': 1,
#                      'height': 0,
#                      'leaf': True,
#                      'nodePar.pch': 19,
#                      'nodePar.cex': 2,
#                      'nodePar.lab.cex': 0.25,
#                      'nodePar.lab.col': '#6C00BF',
#                      'nodePar.col': '#6C00BF',
#                      'cell_set_accession': 'CS201908210_11',
#                      'original_label': 'Inh L1-2 VIP TSPAN12',
#                      'cell_set_label': 'MTG 011',
#                      'cell_set_preferred_alias': 'Inh L1-2 VIP TSPAN12',
#                      'cell_set_aligned_alias': '',
#                      'cell_set_additional_aliases': '',
#                      'cell_set_structure': 'neocortex',
#                      'cell_set_alias_assignee': 'Trygve Bakken||',
#                      'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                      'cell_set_ontology_tag': 'UBERON:0001950',
#                      'taxonomy_id': 'CCN201908210',
#                      '_row': 'Inh L1-2 VIP TSPAN12'}]},
#                   {'leaf_attributes': [{'label': 'Inh L1-4 VIP CHRNA6',
#                      'members': 1,
#                      'height': 0,
#                      'leaf': True,
#                      'nodePar.pch': 19,
#                      'nodePar.cex': 2,
#                      'nodePar.lab.cex': 0.25,
#                      'nodePar.lab.col': '#7A0099',
#                      'nodePar.col': '#7A0099',
#                      'cell_set_accession': 'CS201908210_12',
#                      'original_label': 'Inh L1-4 VIP CHRNA6',
#                      'cell_set_label': 'MTG 012',
#                      'cell_set_preferred_alias': 'Inh L1-4 VIP CHRNA6',
#                      'cell_set_aligned_alias': '',
#                      'cell_set_additional_aliases': '',
#                      'cell_set_structure': 'neocortex',
#                      'cell_set_alias_assignee': 'Trygve Bakken||',
#                      'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                      'cell_set_ontology_tag': 'UBERON:0001950',
#                      'taxonomy_id': 'CCN201908210',
#                      '_row': 'Inh L1-4 VIP CHRNA6'}]}]}]}]},
#             {'node_attributes': [{'members': 2,
#                'midpoint': 0.5,
#                'height': 0.172,
#                'label': '',
#                'cell_set_accession': 'CS201908210_92',
#                'original_label': 'n17',
#                'cell_set_label': 'MTG 013-014',
#                'cell_set_preferred_alias': '',
#                'cell_set_aligned_alias': '',
#                'cell_set_additional_aliases': '',
#                'cell_set_structure': 'neocortex',
#                'cell_set_alias_assignee': 'Trygve Bakken||',
#                'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                'cell_set_ontology_tag': 'UBERON:0001950',
#                'taxonomy_id': 'CCN201908210',
#                '_row': 'n17'}],
#              'children': [{'leaf_attributes': [{'label': 'Inh L1-3 VIP ADAMTSL1',
#                  'members': 1,
#                  'height': 0,
#                  'leaf': True,
#                  'nodePar.pch': 19,
#                  'nodePar.cex': 2,
#                  'nodePar.lab.cex': 0.25,
#                  'nodePar.lab.col': '#7779BF',
#                  'nodePar.col': '#7779BF',
#                  'cell_set_accession': 'CS201908210_13',
#                  'original_label': 'Inh L1-3 VIP ADAMTSL1',
#                  'cell_set_label': 'MTG 013',
#                  'cell_set_preferred_alias': 'Inh L1-3 VIP ADAMTSL1',
#                  'cell_set_aligned_alias': '',
#                  'cell_set_additional_aliases': '',
#                  'cell_set_structure': 'neocortex',
#                  'cell_set_alias_assignee': 'Trygve Bakken||',
#                  'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                  'cell_set_ontology_tag': 'UBERON:0001950',
#                  'taxonomy_id': 'CCN201908210',
#                  '_row': 'Inh L1-3 VIP ADAMTSL1'}]},
#               {'leaf_attributes': [{'label': 'Inh L1-4 VIP PENK',
#                  'members': 1,
#                  'height': 0,
#                  'leaf': True,
#                  'nodePar.pch': 19,
#                  'nodePar.cex': 2,
#                  'nodePar.lab.cex': 0.25,
#                  'nodePar.lab.col': '#3C3D73',
#                  'nodePar.col': '#3C3D73',
#                  'cell_set_accession': 'CS201908210_14',
#                  'original_label': 'Inh L1-4 VIP PENK',
#                  'cell_set_label': 'MTG 014',
#                  'cell_set_preferred_alias': 'Inh L1-4 VIP PENK',
#                  'cell_set_aligned_alias': '',
#                  'cell_set_additional_aliases': '',
#                  'cell_set_structure': 'neocortex',
#                  'cell_set_alias_assignee': 'Trygve Bakken||',
#                  'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                  'cell_set_ontology_tag': 'UBERON:0001950',
#                  'taxonomy_id': 'CCN201908210',
#                  '_row': 'Inh L1-4 VIP PENK'}]}]}]},
#           {'node_attributes': [{'members': 13,
#              'midpoint': 5.5938,
#              'height': 0.2296,
#              'label': '',
#              'cell_set_accession': 'CS201908210_93',
#              'original_label': 'n18',
#              'cell_set_label': 'MTG 015-027',
#              'cell_set_preferred_alias': '',
#              'cell_set_aligned_alias': '',
#              'cell_set_additional_aliases': '',
#              'cell_set_structure': 'neocortex',
#              'cell_set_alias_assignee': 'Trygve Bakken||',
#              'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#              'cell_set_ontology_tag': 'UBERON:0001950',
#              'taxonomy_id': 'CCN201908210',
#              '_row': 'n18'}],
#            'children': [{'node_attributes': [{'members': 5,
#                'midpoint': 2.375,
#                'height': 0.2035,
#                'label': '',
#                'cell_set_accession': 'CS201908210_94',
#                'original_label': 'n19',
#                'cell_set_label': 'MTG 015-019',
#                'cell_set_preferred_alias': '',
#                'cell_set_aligned_alias': '',
#                'cell_set_additional_aliases': '',
#                'cell_set_structure': 'neocortex',
#                'cell_set_alias_assignee': 'Trygve Bakken||',
#                'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                'cell_set_ontology_tag': 'UBERON:0001950',
#                'taxonomy_id': 'CCN201908210',
#                '_row': 'n19'}],
#              'children': [{'node_attributes': [{'members': 3,
#                  'midpoint': 1.25,
#                  'height': 0.1598,
#                  'label': '',
#                  'cell_set_accession': 'CS201908210_95',
#                  'original_label': 'n20',
#                  'cell_set_label': 'MTG 015-017',
#                  'cell_set_preferred_alias': '',
#                  'cell_set_aligned_alias': '',
#                  'cell_set_additional_aliases': '',
#                  'cell_set_structure': 'neocortex',
#                  'cell_set_alias_assignee': 'Trygve Bakken||',
#                  'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                  'cell_set_ontology_tag': 'UBERON:0001950',
#                  'taxonomy_id': 'CCN201908210',
#                  '_row': 'n20'}],
#                'children': [{'node_attributes': [{'members': 2,
#                    'midpoint': 0.5,
#                    'height': 0.1211,
#                    'label': '',
#                    'cell_set_accession': 'CS201908210_96',
#                    'original_label': 'n21',
#                    'cell_set_label': 'MTG 015-016',
#                    'cell_set_preferred_alias': '',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'n21'}],
#                  'children': [{'leaf_attributes': [{'label': 'Inh L2-6 VIP QPCT',
#                      'members': 1,
#                      'height': 0,
#                      'leaf': True,
#                      'nodePar.pch': 19,
#                      'nodePar.cex': 2,
#                      'nodePar.lab.cex': 0.25,
#                      'nodePar.lab.col': '#A700FF',
#                      'nodePar.col': '#A700FF',
#                      'cell_set_accession': 'CS201908210_15',
#                      'original_label': 'Inh L2-6 VIP QPCT',
#                      'cell_set_label': 'MTG 015',
#                      'cell_set_preferred_alias': 'Inh L2-6 VIP QPCT',
#                      'cell_set_aligned_alias': '',
#                      'cell_set_additional_aliases': '',
#                      'cell_set_structure': 'neocortex',
#                      'cell_set_alias_assignee': 'Trygve Bakken||',
#                      'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                      'cell_set_ontology_tag': 'UBERON:0001950',
#                      'taxonomy_id': 'CCN201908210',
#                      '_row': 'Inh L2-6 VIP QPCT'}]},
#                   {'leaf_attributes': [{'label': 'Inh L3-6 VIP HS3ST3A1',
#                      'members': 1,
#                      'height': 0,
#                      'leaf': True,
#                      'nodePar.pch': 19,
#                      'nodePar.cex': 2,
#                      'nodePar.lab.cex': 0.25,
#                      'nodePar.lab.col': '#FF00FF',
#                      'nodePar.col': '#FF00FF',
#                      'cell_set_accession': 'CS201908210_16',
#                      'original_label': 'Inh L3-6 VIP HS3ST3A1',
#                      'cell_set_label': 'MTG 016',
#                      'cell_set_preferred_alias': 'Inh L3-6 VIP HS3ST3A1',
#                      'cell_set_aligned_alias': '',
#                      'cell_set_additional_aliases': '',
#                      'cell_set_structure': 'neocortex',
#                      'cell_set_alias_assignee': 'Trygve Bakken||',
#                      'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                      'cell_set_ontology_tag': 'UBERON:0001950',
#                      'taxonomy_id': 'CCN201908210',
#                      '_row': 'Inh L3-6 VIP HS3ST3A1'}]}]},
#                 {'leaf_attributes': [{'members': 1,
#                    'height': 0,
#                    'label': 'Inh L1-2 VIP PCDH20',
#                    'leaf': True,
#                    'nodePar.pch': 19,
#                    'nodePar.cex': 2,
#                    'nodePar.lab.cex': 0.25,
#                    'nodePar.lab.col': '#BD3D9A',
#                    'nodePar.col': '#BD3D9A',
#                    'cell_set_accession': 'CS201908210_17',
#                    'original_label': 'Inh L1-2 VIP PCDH20',
#                    'cell_set_label': 'MTG 017',
#                    'cell_set_preferred_alias': 'Inh L1-2 VIP PCDH20',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'Inh L1-2 VIP PCDH20'}]}]},
#               {'node_attributes': [{'members': 2,
#                  'midpoint': 0.5,
#                  'height': 0.1208,
#                  'label': '',
#                  'cell_set_accession': 'CS201908210_97',
#                  'original_label': 'n22',
#                  'cell_set_label': 'MTG 018-019',
#                  'cell_set_preferred_alias': '',
#                  'cell_set_aligned_alias': '',
#                  'cell_set_additional_aliases': '',
#                  'cell_set_structure': 'neocortex',
#                  'cell_set_alias_assignee': 'Trygve Bakken||',
#                  'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                  'cell_set_ontology_tag': 'UBERON:0001950',
#                  'taxonomy_id': 'CCN201908210',
#                  '_row': 'n22'}],
#                'children': [{'leaf_attributes': [{'label': 'Inh L2-5 VIP SERPINF1',
#                    'members': 1,
#                    'height': 0,
#                    'leaf': True,
#                    'nodePar.pch': 19,
#                    'nodePar.cex': 2,
#                    'nodePar.lab.cex': 0.25,
#                    'nodePar.lab.col': '#B09FFF',
#                    'nodePar.col': '#B09FFF',
#                    'cell_set_accession': 'CS201908210_18',
#                    'original_label': 'Inh L2-5 VIP SERPINF1',
#                    'cell_set_label': 'MTG 018',
#                    'cell_set_preferred_alias': 'Inh L2-5 VIP SERPINF1',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'Inh L2-5 VIP SERPINF1'}]},
#                 {'leaf_attributes': [{'label': 'Inh L2-5 VIP TYR',
#                    'members': 1,
#                    'height': 0,
#                    'leaf': True,
#                    'nodePar.pch': 19,
#                    'nodePar.cex': 2,
#                    'nodePar.lab.cex': 0.25,
#                    'nodePar.lab.col': '#FF4DC1',
#                    'nodePar.col': '#FF4DC1',
#                    'cell_set_accession': 'CS201908210_19',
#                    'original_label': 'Inh L2-5 VIP TYR',
#                    'cell_set_label': 'MTG 019',
#                    'cell_set_preferred_alias': 'Inh L2-5 VIP TYR',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'Inh L2-5 VIP TYR'}]}]}]},
#             {'node_attributes': [{'members': 8,
#                'midpoint': 3.8125,
#                'height': 0.188,
#                'label': '',
#                'cell_set_accession': 'CS201908210_98',
#                'original_label': 'n23',
#                'cell_set_label': 'MTG 020-027',
#                'cell_set_preferred_alias': '',
#                'cell_set_aligned_alias': '',
#                'cell_set_additional_aliases': '',
#                'cell_set_structure': 'neocortex',
#                'cell_set_alias_assignee': 'Trygve Bakken||',
#                'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                'cell_set_ontology_tag': 'UBERON:0001950',
#                'taxonomy_id': 'CCN201908210',
#                '_row': 'n23'}],
#              'children': [{'node_attributes': [{'members': 4,
#                  'midpoint': 2.125,
#                  'height': 0.1341,
#                  'label': '',
#                  'cell_set_accession': 'CS201908210_99',
#                  'original_label': 'n24',
#                  'cell_set_label': 'MTG 020-023',
#                  'cell_set_preferred_alias': '',
#                  'cell_set_aligned_alias': '',
#                  'cell_set_additional_aliases': '',
#                  'cell_set_structure': 'neocortex',
#                  'cell_set_alias_assignee': 'Trygve Bakken||',
#                  'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                  'cell_set_ontology_tag': 'UBERON:0001950',
#                  'taxonomy_id': 'CCN201908210',
#                  '_row': 'n24'}],
#                'children': [{'node_attributes': [{'members': 3,
#                    'midpoint': 1.25,
#                    'height': 0.0953,
#                    'label': '',
#                    'cell_set_accession': 'CS201908210_100',
#                    'original_label': 'n25',
#                    'cell_set_label': 'MTG 020-022',
#                    'cell_set_preferred_alias': '',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'n25'}],
#                  'children': [{'node_attributes': [{'members': 2,
#                      'midpoint': 0.5,
#                      'height': 0.0836,
#                      'label': '',
#                      'cell_set_accession': 'CS201908210_101',
#                      'original_label': 'n26',
#                      'cell_set_label': 'MTG 020-021',
#                      'cell_set_preferred_alias': '',
#                      'cell_set_aligned_alias': '',
#                      'cell_set_additional_aliases': '',
#                      'cell_set_structure': 'neocortex',
#                      'cell_set_alias_assignee': 'Trygve Bakken||',
#                      'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                      'cell_set_ontology_tag': 'UBERON:0001950',
#                      'taxonomy_id': 'CCN201908210',
#                      '_row': 'n26'}],
#                    'children': [{'leaf_attributes': [{'label': 'Inh L1-3 VIP CHRM2',
#                        'members': 1,
#                        'height': 0,
#                        'leaf': True,
#                        'nodePar.pch': 19,
#                        'nodePar.cex': 2,
#                        'nodePar.lab.cex': 0.25,
#                        'nodePar.lab.col': '#9FAAFF',
#                        'nodePar.col': '#9FAAFF',
#                        'cell_set_accession': 'CS201908210_20',
#                        'original_label': 'Inh L1-3 VIP CHRM2',
#                        'cell_set_label': 'MTG 020',
#                        'cell_set_preferred_alias': 'Inh L1-3 VIP CHRM2',
#                        'cell_set_aligned_alias': '',
#                        'cell_set_additional_aliases': '',
#                        'cell_set_structure': 'neocortex',
#                        'cell_set_alias_assignee': 'Trygve Bakken||',
#                        'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                        'cell_set_ontology_tag': 'UBERON:0001950',
#                        'taxonomy_id': 'CCN201908210',
#                        '_row': 'Inh L1-3 VIP CHRM2'}]},
#                     {'leaf_attributes': [{'label': 'Inh L2-4 VIP CBLN1',
#                        'members': 1,
#                        'height': 0,
#                        'leaf': True,
#                        'nodePar.pch': 19,
#                        'nodePar.cex': 2,
#                        'nodePar.lab.cex': 0.25,
#                        'nodePar.lab.col': '#756FB3',
#                        'nodePar.col': '#756FB3',
#                        'cell_set_accession': 'CS201908210_21',
#                        'original_label': 'Inh L2-4 VIP CBLN1',
#                        'cell_set_label': 'MTG 021',
#                        'cell_set_preferred_alias': 'Inh L2-4 VIP CBLN1',
#                        'cell_set_aligned_alias': '',
#                        'cell_set_additional_aliases': '',
#                        'cell_set_structure': 'neocortex',
#                        'cell_set_alias_assignee': 'Trygve Bakken||',
#                        'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                        'cell_set_ontology_tag': 'UBERON:0001950',
#                        'taxonomy_id': 'CCN201908210',
#                        '_row': 'Inh L2-4 VIP CBLN1'}]}]},
#                   {'leaf_attributes': [{'members': 1,
#                      'height': 0,
#                      'label': 'Inh L1-3 VIP CCDC184',
#                      'leaf': True,
#                      'nodePar.pch': 19,
#                      'nodePar.cex': 2,
#                      'nodePar.lab.cex': 0.25,
#                      'nodePar.lab.col': '#FF00B3',
#                      'nodePar.col': '#FF00B3',
#                      'cell_set_accession': 'CS201908210_22',
#                      'original_label': 'Inh L1-3 VIP CCDC184',
#                      'cell_set_label': 'MTG 022',
#                      'cell_set_preferred_alias': 'Inh L1-3 VIP CCDC184',
#                      'cell_set_aligned_alias': '',
#                      'cell_set_additional_aliases': '',
#                      'cell_set_structure': 'neocortex',
#                      'cell_set_alias_assignee': 'Trygve Bakken||',
#                      'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                      'cell_set_ontology_tag': 'UBERON:0001950',
#                      'taxonomy_id': 'CCN201908210',
#                      '_row': 'Inh L1-3 VIP CCDC184'}]}]},
#                 {'leaf_attributes': [{'members': 1,
#                    'height': 0,
#                    'label': 'Inh L1-3 VIP GGH',
#                    'leaf': True,
#                    'nodePar.pch': 19,
#                    'nodePar.cex': 2,
#                    'nodePar.lab.cex': 0.25,
#                    'nodePar.lab.col': '#B3128A',
#                    'nodePar.col': '#B3128A',
#                    'cell_set_accession': 'CS201908210_23',
#                    'original_label': 'Inh L1-3 VIP GGH',
#                    'cell_set_label': 'MTG 023',
#                    'cell_set_preferred_alias': 'Inh L1-3 VIP GGH',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'Inh L1-3 VIP GGH'}]}]},
#               {'node_attributes': [{'members': 4,
#                  'midpoint': 1.5,
#                  'height': 0.1729,
#                  'label': '',
#                  'cell_set_accession': 'CS201908210_102',
#                  'original_label': 'n27',
#                  'cell_set_label': 'MTG 024-027',
#                  'cell_set_preferred_alias': '',
#                  'cell_set_aligned_alias': '',
#                  'cell_set_additional_aliases': '',
#                  'cell_set_structure': 'neocortex',
#                  'cell_set_alias_assignee': 'Trygve Bakken||',
#                  'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                  'cell_set_ontology_tag': 'UBERON:0001950',
#                  'taxonomy_id': 'CCN201908210',
#                  '_row': 'n27'}],
#                'children': [{'node_attributes': [{'members': 2,
#                    'midpoint': 0.5,
#                    'height': 0.0934,
#                    'label': '',
#                    'cell_set_accession': 'CS201908210_103',
#                    'original_label': 'n28',
#                    'cell_set_label': 'MTG 024-025',
#                    'cell_set_preferred_alias': '',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'n28'}],
#                  'children': [{'leaf_attributes': [{'label': 'Inh L1-2 VIP LBH',
#                      'members': 1,
#                      'height': 0,
#                      'leaf': True,
#                      'nodePar.pch': 19,
#                      'nodePar.cex': 2,
#                      'nodePar.lab.cex': 0.25,
#                      'nodePar.lab.col': '#AF00E6',
#                      'nodePar.col': '#AF00E6',
#                      'cell_set_accession': 'CS201908210_24',
#                      'original_label': 'Inh L1-2 VIP LBH',
#                      'cell_set_label': 'MTG 024',
#                      'cell_set_preferred_alias': 'Inh L1-2 VIP LBH',
#                      'cell_set_aligned_alias': '',
#                      'cell_set_additional_aliases': '',
#                      'cell_set_structure': 'neocortex',
#                      'cell_set_alias_assignee': 'Trygve Bakken||',
#                      'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                      'cell_set_ontology_tag': 'UBERON:0001950',
#                      'taxonomy_id': 'CCN201908210',
#                      '_row': 'Inh L1-2 VIP LBH'}]},
#                   {'leaf_attributes': [{'label': 'Inh L2-3 VIP CASC6',
#                      'members': 1,
#                      'height': 0,
#                      'leaf': True,
#                      'nodePar.pch': 19,
#                      'nodePar.cex': 2,
#                      'nodePar.lab.cex': 0.25,
#                      'nodePar.lab.col': '#992E81',
#                      'nodePar.col': '#992E81',
#                      'cell_set_accession': 'CS201908210_25',
#                      'original_label': 'Inh L2-3 VIP CASC6',
#                      'cell_set_label': 'MTG 025',
#                      'cell_set_preferred_alias': 'Inh L2-3 VIP CASC6',
# ...
#              'cell_set_preferred_alias': 'Exc L5-6 FEZF2 ABO',
#              'cell_set_aligned_alias': 'L6 CT',
#              'cell_set_additional_aliases': '',
#              'cell_set_structure': 'neocortex',
#              'cell_set_alias_assignee': 'Trygve Bakken|Bosiljka Tasic|',
#              'cell_set_alias_citation': '10.1038/s41586-019-1506-7|10.1038/s41586-018-0654-5|',
#              'cell_set_ontology_tag': 'UBERON:0001950',
#              'taxonomy_id': 'CCN201908210',
#              '_row': 'Exc L5-6 FEZF2 ABO'}]},
#           {'node_attributes': [{'members': 4,
#              'midpoint': 2.125,
#              'height': 0.1735,
#              'label': '',
#              'cell_set_accession': 'CS201908210_142',
#              'original_label': 'n67',
#              'cell_set_label': 'MTG 066-069',
#              'cell_set_preferred_alias': '',
#              'cell_set_aligned_alias': 'L6b',
#              'cell_set_additional_aliases': '',
#              'cell_set_structure': 'neocortex',
#              'cell_set_alias_assignee': 'Trygve Bakken||',
#              'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#              'cell_set_ontology_tag': 'UBERON:0001950',
#              'taxonomy_id': 'CCN201908210',
#              '_row': 'n67'}],
#            'children': [{'node_attributes': [{'members': 3,
#                'midpoint': 1.25,
#                'height': 0.1438,
#                'label': '',
#                'cell_set_accession': 'CS201908210_143',
#                'original_label': 'n68',
#                'cell_set_label': 'MTG 066-068',
#                'cell_set_preferred_alias': '',
#                'cell_set_aligned_alias': '',
#                'cell_set_additional_aliases': '',
#                'cell_set_structure': 'neocortex',
#                'cell_set_alias_assignee': 'Trygve Bakken||',
#                'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                'cell_set_ontology_tag': 'UBERON:0001950',
#                'taxonomy_id': 'CCN201908210',
#                '_row': 'n68'}],
#              'children': [{'node_attributes': [{'members': 2,
#                  'midpoint': 0.5,
#                  'height': 0.1058,
#                  'label': '',
#                  'cell_set_accession': 'CS201908210_144',
#                  'original_label': 'n69',
#                  'cell_set_label': 'MTG 066-067',
#                  'cell_set_preferred_alias': '',
#                  'cell_set_aligned_alias': '',
#                  'cell_set_additional_aliases': '',
#                  'cell_set_structure': 'neocortex',
#                  'cell_set_alias_assignee': 'Trygve Bakken||',
#                  'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                  'cell_set_ontology_tag': 'UBERON:0001950',
#                  'taxonomy_id': 'CCN201908210',
#                  '_row': 'n69'}],
#                'children': [{'leaf_attributes': [{'label': 'Exc L6 FEZF2 SCUBE1',
#                    'members': 1,
#                    'height': 0,
#                    'leaf': True,
#                    'nodePar.pch': 19,
#                    'nodePar.cex': 2,
#                    'nodePar.lab.cex': 0.25,
#                    'nodePar.lab.col': '#388899',
#                    'nodePar.col': '#388899',
#                    'cell_set_accession': 'CS201908210_66',
#                    'original_label': 'Exc L6 FEZF2 SCUBE1',
#                    'cell_set_label': 'MTG 066',
#                    'cell_set_preferred_alias': 'Exc L6 FEZF2 SCUBE1',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'Exc L6 FEZF2 SCUBE1'}]},
#                 {'leaf_attributes': [{'label': 'Exc L5-6 FEZF2 IL15',
#                    'members': 1,
#                    'height': 0,
#                    'leaf': True,
#                    'nodePar.pch': 19,
#                    'nodePar.cex': 2,
#                    'nodePar.lab.cex': 0.25,
#                    'nodePar.lab.col': '#336D99',
#                    'nodePar.col': '#336D99',
#                    'cell_set_accession': 'CS201908210_67',
#                    'original_label': 'Exc L5-6 FEZF2 IL15',
#                    'cell_set_label': 'MTG 067',
#                    'cell_set_preferred_alias': 'Exc L5-6 FEZF2 IL15',
#                    'cell_set_aligned_alias': '',
#                    'cell_set_additional_aliases': '',
#                    'cell_set_structure': 'neocortex',
#                    'cell_set_alias_assignee': 'Trygve Bakken||',
#                    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                    'cell_set_ontology_tag': 'UBERON:0001950',
#                    'taxonomy_id': 'CCN201908210',
#                    '_row': 'Exc L5-6 FEZF2 IL15'}]}]},
#               {'leaf_attributes': [{'members': 1,
#                  'height': 0,
#                  'label': 'Exc L6 FEZF2 OR2T8',
#                  'leaf': True,
#                  'nodePar.pch': 19,
#                  'nodePar.cex': 2,
#                  'nodePar.lab.cex': 0.25,
#                  'nodePar.lab.col': '#254566',
#                  'nodePar.col': '#254566',
#                  'cell_set_accession': 'CS201908210_68',
#                  'original_label': 'Exc L6 FEZF2 OR2T8',
#                  'cell_set_label': 'MTG 068',
#                  'cell_set_preferred_alias': 'Exc L6 FEZF2 OR2T8',
#                  'cell_set_aligned_alias': '',
#                  'cell_set_additional_aliases': '',
#                  'cell_set_structure': 'neocortex',
#                  'cell_set_alias_assignee': 'Trygve Bakken||',
#                  'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                  'cell_set_ontology_tag': 'UBERON:0001950',
#                  'taxonomy_id': 'CCN201908210',
#                  '_row': 'Exc L6 FEZF2 OR2T8'}]}]},
#             {'leaf_attributes': [{'members': 1,
#                'height': 0,
#                'label': 'Exc L5-6 FEZF2 EFTUD1P1',
#                'leaf': True,
#                'nodePar.pch': 19,
#                'nodePar.cex': 2,
#                'nodePar.lab.cex': 0.25,
#                'nodePar.lab.col': '#335280',
#                'nodePar.col': '#335280',
#                'cell_set_accession': 'CS201908210_69',
#                'original_label': 'Exc L5-6 FEZF2 EFTUD1P1',
#                'cell_set_label': 'MTG 069',
#                'cell_set_preferred_alias': 'Exc L5-6 FEZF2 EFTUD1P1',
#                'cell_set_aligned_alias': '',
#                'cell_set_additional_aliases': '',
#                'cell_set_structure': 'neocortex',
#                'cell_set_alias_assignee': 'Trygve Bakken||',
#                'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                'cell_set_ontology_tag': 'UBERON:0001950',
#                'taxonomy_id': 'CCN201908210',
#                '_row': 'Exc L5-6 FEZF2 EFTUD1P1'}]}]}]}]}]}]},
#   {'node_attributes': [{'members': 6,
#      'midpoint': 3.9688,
#      'height': 0.8209,
#      'label': 'Non-neuronal',
#      'cell_set_accession': 'CS201908210_145',
#      'original_label': 'n70',
#      'cell_set_label': 'MTG 070-075',
#      'cell_set_preferred_alias': 'Non-neuronal',
#      'cell_set_aligned_alias': 'Non-neuronal',
#      'cell_set_additional_aliases': '',
#      'cell_set_structure': 'neocortex',
#      'cell_set_alias_assignee': 'Trygve Bakken||',
#      'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#      'cell_set_ontology_tag': 'UBERON:0001950',
#      'taxonomy_id': 'CCN201908210',
#      '_row': 'n70'}],
#    'children': [{'node_attributes': [{'members': 5,
#        'midpoint': 2.9375,
#        'height': 0.7567,
#        'label': '',
#        'cell_set_accession': 'CS201908210_146',
#        'original_label': 'n71',
#        'cell_set_label': 'MTG 070-074',
#        'cell_set_preferred_alias': '',
#        'cell_set_aligned_alias': '',
#        'cell_set_additional_aliases': '',
#        'cell_set_structure': 'neocortex',
#        'cell_set_alias_assignee': 'Trygve Bakken||',
#        'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#        'cell_set_ontology_tag': 'UBERON:0001950',
#        'taxonomy_id': 'CCN201908210',
#        '_row': 'n71'}],
#      'children': [{'node_attributes': [{'members': 4,
#          'midpoint': 1.875,
#          'height': 0.7506,
#          'label': '',
#          'cell_set_accession': 'CS201908210_147',
#          'original_label': 'n72',
#          'cell_set_label': 'MTG 070-073',
#          'cell_set_preferred_alias': '',
#          'cell_set_aligned_alias': '',
#          'cell_set_additional_aliases': '',
#          'cell_set_structure': 'neocortex',
#          'cell_set_alias_assignee': 'Trygve Bakken||',
#          'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#          'cell_set_ontology_tag': 'UBERON:0001950',
#          'taxonomy_id': 'CCN201908210',
#          '_row': 'n72'}],
#        'children': [{'node_attributes': [{'members': 3,
#            'midpoint': 0.75,
#            'height': 0.6142,
#            'label': '',
#            'cell_set_accession': 'CS201908210_148',
#            'original_label': 'n73',
#            'cell_set_label': 'MTG 070-072',
#            'cell_set_preferred_alias': '',
#            'cell_set_aligned_alias': '',
#            'cell_set_additional_aliases': '',
#            'cell_set_structure': 'neocortex',
#            'cell_set_alias_assignee': 'Trygve Bakken||',
#            'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#            'cell_set_ontology_tag': 'UBERON:0001950',
#            'taxonomy_id': 'CCN201908210',
#            '_row': 'n73'}],
#          'children': [{'leaf_attributes': [{'members': 1,
#              'height': 0,
#              'label': 'OPC L1-6 PDGFRA',
#              'leaf': True,
#              'nodePar.pch': 19,
#              'nodePar.cex': 2,
#              'nodePar.lab.cex': 0.25,
#              'nodePar.lab.col': '#6B998D',
#              'nodePar.col': '#6B998D',
#              'cell_set_accession': 'CS201908210_70',
#              'original_label': 'OPC L1-6 PDGFRA',
#              'cell_set_label': 'MTG 070',
#              'cell_set_preferred_alias': 'OPC L1-6 PDGFRA',
#              'cell_set_aligned_alias': 'OPC',
#              'cell_set_additional_aliases': '',
#              'cell_set_structure': 'neocortex',
#              'cell_set_alias_assignee': 'Trygve Bakken||',
#              'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#              'cell_set_ontology_tag': 'UBERON:0001950',
#              'taxonomy_id': 'CCN201908210',
#              '_row': 'OPC L1-6 PDGFRA'}]},
#           {'node_attributes': [{'members': 2,
#              'midpoint': 0.5,
#              'height': 0.1304,
#              'label': '',
#              'cell_set_accession': 'CS201908210_149',
#              'original_label': 'n74',
#              'cell_set_label': 'MTG 071-072',
#              'cell_set_preferred_alias': '',
#              'cell_set_aligned_alias': 'Astro',
#              'cell_set_additional_aliases': '',
#              'cell_set_structure': 'neocortex',
#              'cell_set_alias_assignee': 'Trygve Bakken||',
#              'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#              'cell_set_ontology_tag': 'UBERON:0001950',
#              'taxonomy_id': 'CCN201908210',
#              '_row': 'n74'}],
#            'children': [{'leaf_attributes': [{'label': 'Astro L1-6 FGFR3 SLC14A1',
#                'members': 1,
#                'height': 0,
#                'leaf': True,
#                'nodePar.pch': 19,
#                'nodePar.cex': 2,
#                'nodePar.lab.cex': 0.25,
#                'nodePar.lab.col': '#665C47',
#                'nodePar.col': '#665C47',
#                'cell_set_accession': 'CS201908210_71',
#                'original_label': 'Astro L1-6 FGFR3 SLC14A1',
#                'cell_set_label': 'MTG 071',
#                'cell_set_preferred_alias': 'Astro L1-6 FGFR3 SLC14A1',
#                'cell_set_aligned_alias': '',
#                'cell_set_additional_aliases': '',
#                'cell_set_structure': 'neocortex',
#                'cell_set_alias_assignee': 'Trygve Bakken||',
#                'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                'cell_set_ontology_tag': 'UBERON:0001950',
#                'taxonomy_id': 'CCN201908210',
#                '_row': 'Astro L1-6 FGFR3 SLC14A1'}]},
#             {'leaf_attributes': [{'label': 'Astro L1-2 FGFR3 GFAP',
#                'members': 1,
#                'height': 0,
#                'leaf': True,
#                'nodePar.pch': 19,
#                'nodePar.cex': 2,
#                'nodePar.lab.cex': 0.25,
#                'nodePar.lab.col': '#6B8059',
#                'nodePar.col': '#6B8059',
#                'cell_set_accession': 'CS201908210_72',
#                'original_label': 'Astro L1-2 FGFR3 GFAP',
#                'cell_set_label': 'MTG 072',
#                'cell_set_preferred_alias': 'Astro L1-2 FGFR3 GFAP',
#                'cell_set_aligned_alias': '',
#                'cell_set_additional_aliases': '',
#                'cell_set_structure': 'neocortex',
#                'cell_set_alias_assignee': 'Trygve Bakken||',
#                'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#                'cell_set_ontology_tag': 'UBERON:0001950',
#                'taxonomy_id': 'CCN201908210',
#                '_row': 'Astro L1-2 FGFR3 GFAP'}]}]}]},
#         {'leaf_attributes': [{'members': 1,
#            'height': 0,
#            'label': 'Oligo L1-6 OPALIN',
#            'leaf': True,
#            'nodePar.pch': 19,
#            'nodePar.cex': 2,
#            'nodePar.lab.cex': 0.25,
#            'nodePar.lab.col': '#476662',
#            'nodePar.col': '#476662',
#            'cell_set_accession': 'CS201908210_73',
#            'original_label': 'Oligo L1-6 OPALIN',
#            'cell_set_label': 'MTG 073',
#            'cell_set_preferred_alias': 'Oligo L1-6 OPALIN',
#            'cell_set_aligned_alias': 'Oligo',
#            'cell_set_additional_aliases': '',
#            'cell_set_structure': 'neocortex',
#            'cell_set_alias_assignee': 'Trygve Bakken||',
#            'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#            'cell_set_ontology_tag': 'UBERON:0001950',
#            'taxonomy_id': 'CCN201908210',
#            '_row': 'Oligo L1-6 OPALIN'}]}]},
#       {'leaf_attributes': [{'members': 1,
#          'height': 0,
#          'label': 'Endo L2-6 NOSTRIN',
#          'leaf': True,
#          'nodePar.pch': 19,
#          'nodePar.cex': 2,
#          'nodePar.lab.cex': 0.25,
#          'nodePar.lab.col': '#99796B',
#          'nodePar.col': '#99796B',
#          'cell_set_accession': 'CS201908210_74',
#          'original_label': 'Endo L2-6 NOSTRIN',
#          'cell_set_label': 'MTG 074',
#          'cell_set_preferred_alias': 'Endo L2-6 NOSTRIN',
#          'cell_set_aligned_alias': 'Endo',
#          'cell_set_additional_aliases': '',
#          'cell_set_structure': 'neocortex',
#          'cell_set_alias_assignee': 'Trygve Bakken||',
#          'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#          'cell_set_ontology_tag': 'UBERON:0001950',
#          'taxonomy_id': 'CCN201908210',
#          '_row': 'Endo L2-6 NOSTRIN'}]}]},
#     {'leaf_attributes': [{'members': 1,
#        'height': 0,
#        'label': 'Micro L1-6 TYROBP',
#        'leaf': True,
#        'nodePar.pch': 19,
#        'nodePar.cex': 2,
#        'nodePar.lab.cex': 0.25,
#        'nodePar.lab.col': '#598069',
#        'nodePar.col': '#598069',
#        'cell_set_accession': 'CS201908210_75',
#        'original_label': 'Micro L1-6 TYROBP',
#        'cell_set_label': 'MTG 075',
#        'cell_set_preferred_alias': 'Micro L1-6 TYROBP',
#        'cell_set_aligned_alias': 'Micro-PVM',
#        'cell_set_additional_aliases': '',
#        'cell_set_structure': 'neocortex',
#        'cell_set_alias_assignee': 'Trygve Bakken||',
#        'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#        'cell_set_ontology_tag': 'UBERON:0001950',
#        'taxonomy_id': 'CCN201908210',
#        '_row': 'Micro L1-6 TYROBP'}]}]}]}

# %%
j['node_attributes']
# Out:
# [{'members': 75,
#   'midpoint': 57.5288,
#   'height': 0.9146,
#   'label': '',
#   'cell_set_accession': 'CS201908210_76',
#   'original_label': 'n1',
#   'cell_set_label': 'All cells',
#   'cell_set_preferred_alias': '',
#   'cell_set_aligned_alias': '',
#   'cell_set_additional_aliases': '',
#   'cell_set_structure': 'neocortex',
#   'cell_set_alias_assignee': 'Trygve Bakken||',
#   'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#   'cell_set_ontology_tag': 'UBERON:0001950',
#   'taxonomy_id': 'CCN201908210',
#   '_row': 'n1'}]

# %%
j['children']
# Out:
# {'node_attributes': [{'members': 6,
#    'midpoint': 3.9688,
#    'height': 0.8209,
#    'label': 'Non-neuronal',
#    'cell_set_accession': 'CS201908210_145',
#    'original_label': 'n70',
#    'cell_set_label': 'MTG 070-075',
#    'cell_set_preferred_alias': 'Non-neuronal',
#    'cell_set_aligned_alias': 'Non-neuronal',
#    'cell_set_additional_aliases': '',
#    'cell_set_structure': 'neocortex',
#    'cell_set_alias_assignee': 'Trygve Bakken||',
#    'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#    'cell_set_ontology_tag': 'UBERON:0001950',
#    'taxonomy_id': 'CCN201908210',
#    '_row': 'n70'}],
#  'children': [{'node_attributes': [{'members': 5,
#      'midpoint': 2.9375,
#      'height': 0.7567,
#      'label': '',
#      'cell_set_accession': 'CS201908210_146',
#      'original_label': 'n71',
#      'cell_set_label': 'MTG 070-074',
#      'cell_set_preferred_alias': '',
#      'cell_set_aligned_alias': '',
#      'cell_set_additional_aliases': '',
#      'cell_set_structure': 'neocortex',
#      'cell_set_alias_assignee': 'Trygve Bakken||',
#      'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#      'cell_set_ontology_tag': 'UBERON:0001950',
#      'taxonomy_id': 'CCN201908210',
#      '_row': 'n71'}],
#    'children': [{'node_attributes': [{'members': 4,
#        'midpoint': 1.875,
#        'height': 0.7506,
#        'label': '',
#        'cell_set_accession': 'CS201908210_147',
#        'original_label': 'n72',
#        'cell_set_label': 'MTG 070-073',
#        'cell_set_preferred_alias': '',
#        'cell_set_aligned_alias': '',
#        'cell_set_additional_aliases': '',
#        'cell_set_structure': 'neocortex',
#        'cell_set_alias_assignee': 'Trygve Bakken||',
#        'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#        'cell_set_ontology_tag': 'UBERON:0001950',
#        'taxonomy_id': 'CCN201908210',
#        '_row': 'n72'}],
#      'children': [{'node_attributes': [{'members': 3,
#          'midpoint': 0.75,
#          'height': 0.6142,
#          'label': '',
#          'cell_set_accession': 'CS201908210_148',
#          'original_label': 'n73',
#          'cell_set_label': 'MTG 070-072',
#          'cell_set_preferred_alias': '',
#          'cell_set_aligned_alias': '',
#          'cell_set_additional_aliases': '',
#          'cell_set_structure': 'neocortex',
#          'cell_set_alias_assignee': 'Trygve Bakken||',
#          'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#          'cell_set_ontology_tag': 'UBERON:0001950',
#          'taxonomy_id': 'CCN201908210',
#          '_row': 'n73'}],
#        'children': [{'leaf_attributes': [{'members': 1,
#            'height': 0,
#            'label': 'OPC L1-6 PDGFRA',
#            'leaf': True,
#            'nodePar.pch': 19,
#            'nodePar.cex': 2,
#            'nodePar.lab.cex': 0.25,
#            'nodePar.lab.col': '#6B998D',
#            'nodePar.col': '#6B998D',
#            'cell_set_accession': 'CS201908210_70',
#            'original_label': 'OPC L1-6 PDGFRA',
#            'cell_set_label': 'MTG 070',
#            'cell_set_preferred_alias': 'OPC L1-6 PDGFRA',
#            'cell_set_aligned_alias': 'OPC',
#            'cell_set_additional_aliases': '',
#            'cell_set_structure': 'neocortex',
#            'cell_set_alias_assignee': 'Trygve Bakken||',
#            'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#            'cell_set_ontology_tag': 'UBERON:0001950',
#            'taxonomy_id': 'CCN201908210',
#            '_row': 'OPC L1-6 PDGFRA'}]},
#         {'node_attributes': [{'members': 2,
#            'midpoint': 0.5,
#            'height': 0.1304,
#            'label': '',
#            'cell_set_accession': 'CS201908210_149',
#            'original_label': 'n74',
#            'cell_set_label': 'MTG 071-072',
#            'cell_set_preferred_alias': '',
#            'cell_set_aligned_alias': 'Astro',
#            'cell_set_additional_aliases': '',
#            'cell_set_structure': 'neocortex',
#            'cell_set_alias_assignee': 'Trygve Bakken||',
#            'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#            'cell_set_ontology_tag': 'UBERON:0001950',
#            'taxonomy_id': 'CCN201908210',
#            '_row': 'n74'}],
#          'children': [{'leaf_attributes': [{'label': 'Astro L1-6 FGFR3 SLC14A1',
#              'members': 1,
#              'height': 0,
#              'leaf': True,
#              'nodePar.pch': 19,
#              'nodePar.cex': 2,
#              'nodePar.lab.cex': 0.25,
#              'nodePar.lab.col': '#665C47',
#              'nodePar.col': '#665C47',
#              'cell_set_accession': 'CS201908210_71',
#              'original_label': 'Astro L1-6 FGFR3 SLC14A1',
#              'cell_set_label': 'MTG 071',
#              'cell_set_preferred_alias': 'Astro L1-6 FGFR3 SLC14A1',
#              'cell_set_aligned_alias': '',
#              'cell_set_additional_aliases': '',
#              'cell_set_structure': 'neocortex',
#              'cell_set_alias_assignee': 'Trygve Bakken||',
#              'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#              'cell_set_ontology_tag': 'UBERON:0001950',
#              'taxonomy_id': 'CCN201908210',
#              '_row': 'Astro L1-6 FGFR3 SLC14A1'}]},
#           {'leaf_attributes': [{'label': 'Astro L1-2 FGFR3 GFAP',
#              'members': 1,
#              'height': 0,
#              'leaf': True,
#              'nodePar.pch': 19,
#              'nodePar.cex': 2,
#              'nodePar.lab.cex': 0.25,
#              'nodePar.lab.col': '#6B8059',
#              'nodePar.col': '#6B8059',
#              'cell_set_accession': 'CS201908210_72',
#              'original_label': 'Astro L1-2 FGFR3 GFAP',
#              'cell_set_label': 'MTG 072',
#              'cell_set_preferred_alias': 'Astro L1-2 FGFR3 GFAP',
#              'cell_set_aligned_alias': '',
#              'cell_set_additional_aliases': '',
#              'cell_set_structure': 'neocortex',
#              'cell_set_alias_assignee': 'Trygve Bakken||',
#              'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#              'cell_set_ontology_tag': 'UBERON:0001950',
#              'taxonomy_id': 'CCN201908210',
#              '_row': 'Astro L1-2 FGFR3 GFAP'}]}]}]},
#       {'leaf_attributes': [{'members': 1,
#          'height': 0,
#          'label': 'Oligo L1-6 OPALIN',
#          'leaf': True,
#          'nodePar.pch': 19,
#          'nodePar.cex': 2,
#          'nodePar.lab.cex': 0.25,
#          'nodePar.lab.col': '#476662',
#          'nodePar.col': '#476662',
#          'cell_set_accession': 'CS201908210_73',
#          'original_label': 'Oligo L1-6 OPALIN',
#          'cell_set_label': 'MTG 073',
#          'cell_set_preferred_alias': 'Oligo L1-6 OPALIN',
#          'cell_set_aligned_alias': 'Oligo',
#          'cell_set_additional_aliases': '',
#          'cell_set_structure': 'neocortex',
#          'cell_set_alias_assignee': 'Trygve Bakken||',
#          'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#          'cell_set_ontology_tag': 'UBERON:0001950',
#          'taxonomy_id': 'CCN201908210',
#          '_row': 'Oligo L1-6 OPALIN'}]}]},
#     {'leaf_attributes': [{'members': 1,
#        'height': 0,
#        'label': 'Endo L2-6 NOSTRIN',
#        'leaf': True,
#        'nodePar.pch': 19,
#        'nodePar.cex': 2,
#        'nodePar.lab.cex': 0.25,
#        'nodePar.lab.col': '#99796B',
#        'nodePar.col': '#99796B',
#        'cell_set_accession': 'CS201908210_74',
#        'original_label': 'Endo L2-6 NOSTRIN',
#        'cell_set_label': 'MTG 074',
#        'cell_set_preferred_alias': 'Endo L2-6 NOSTRIN',
#        'cell_set_aligned_alias': 'Endo',
#        'cell_set_additional_aliases': '',
#        'cell_set_structure': 'neocortex',
#        'cell_set_alias_assignee': 'Trygve Bakken||',
#        'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#        'cell_set_ontology_tag': 'UBERON:0001950',
#        'taxonomy_id': 'CCN201908210',
#        '_row': 'Endo L2-6 NOSTRIN'}]}]},
#   {'leaf_attributes': [{'members': 1,
#      'height': 0,
#      'label': 'Micro L1-6 TYROBP',
#      'leaf': True,
#      'nodePar.pch': 19,
#      'nodePar.cex': 2,
#      'nodePar.lab.cex': 0.25,
#      'nodePar.lab.col': '#598069',
#      'nodePar.col': '#598069',
#      'cell_set_accession': 'CS201908210_75',
#      'original_label': 'Micro L1-6 TYROBP',
#      'cell_set_label': 'MTG 075',
#      'cell_set_preferred_alias': 'Micro L1-6 TYROBP',
#      'cell_set_aligned_alias': 'Micro-PVM',
#      'cell_set_additional_aliases': '',
#      'cell_set_structure': 'neocortex',
#      'cell_set_alias_assignee': 'Trygve Bakken||',
#      'cell_set_alias_citation': '10.1038/s41586-019-1506-7||',
#      'cell_set_ontology_tag': 'UBERON:0001950',
#      'taxonomy_id': 'CCN201908210',
#      '_row': 'Micro L1-6 TYROBP'}]}]}

# %%
import warnings

out = {}
def tree_recurse(tree, out, parent_node_id = ''):
    
    """Convert Allen Taxonomy JSON to a list of nodes and edges, where nodes are
    Copies of nodes in Allen JSON & edges are duples - (subject(child), object(parent))
    identified by 'cell_set_accession'.
    
    Args:
        - Tree: Allen taxonomy in JSON, or some subtree of it
        - Output structure (starting point must be { 'nodes': [], 'edges': set() } )
        - parent_node_id: 'cell_set_accession' of parent
        
    """
    if not out:
        out['nodes']= []
        out['edges'] = set()
    if 'node_attributes' in tree.keys():
        if len(tree['node_attributes']) > 1:
            warnings.warn("Don't know how to deal with multiple nodes per recurse")
        ID = tree['node_attributes'][0]['cell_set_accession']
            
        out['nodes'].append(tree['node_attributes'][0])
        if parent_node_id:
            out['edges'].add((ID, parent_node_id))
        if 'children' in tree.keys():
            for c in tree['children']:
                tree_recurse(c, out, parent_node_id = ID)
        else:
            warnings.warn("non leaf node %s has no children" % ID)
    elif 'leaf_attributes' in tree.keys():
        if len(tree['leaf_attributes']) > 1:
            warnings.warn("Don't know how to deal with multiple nodes per recurse")       
        ID = tree['leaf_attributes'][0]['cell_set_accession']
        tree['leaf_attributes'][0]['is_leaf'] = True
        out['nodes'].append(tree['leaf_attributes'][0])
        out['edges'].add((ID, parent_node_id))
        if 'children' in tree.keys():
            warnings.warn('leaf node %s has children!' % ID)
    else:
        warnings.warn("No recognized nodes")
        
tree_recurse(j, out)

# %%
len(out['nodes'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-431928bae5e5> in <module>
# ----> 1 len(out['nodes'])
#
# KeyError: 'nodes'

# %%
## Check for unique attribute values

def unique_attribute_test(nodes):
    # Assuming root node has all keys
    for attr in nodes[0].keys():
        a = {n[attr] for n in out['nodes'] if attr in n.keys()}
        if len(nodes) == len(a):
            print("%s, e.g. '%s' is a unique attribute" % (attr, nodes[1][attr]))
            
unique_attribute_test(out['nodes'])
# Out:
# cell_set_accession, e.g. 'CS201908210_77' is a unique attribute
# original_label, e.g. 'n2' is a unique attribute
# cell_set_label, e.g. 'MTG 001-069' is a unique attribute
# _row, e.g. 'n2' is a unique attribute

# %%
lookup = { n['cell_set_accession']: n['cell_set_preferred_alias'] for n in out['nodes']}
for k,v in lookup:
    parent = []

# %%
# Lets go with cell_set_label as rdfs_label for now.  It may be worth inventing some APs for the others...

# Alternative: 
   # Everything with a cell_set_preferred_alias gets the name "$cell_set_preferred_alias - $taxonomy_id. 
   # We make also classes for these
   # The rest we name "$cell_set_label - $taxonomy_id"
   # other identifiers go in synonyms (at least for now)

# %%
robot_template_seed = { 'ID': 'ID', 
                       'Label': 'LABEL',
                       'PrefLabel': 'skos:prefLabel',
                       'Entity Type': 'TYPE', 
                       'Property Assertions': 'I subcluster_of SPLIT=|',
                       'Synonyms': 'A oio:has_exact_synonym',
                      }

# %%
import pandas as pd

robot_template = pd.DataFrame.from_records([robot_template_seed])
robot_template
# Out:
#    ID         Label Entity Type Property Assertions                 Synonyms
# 0  ID  A rdfs:label     cluster     I subcluster_of  A oio:has_exact_synonym

# %%
dl = [robot_template_seed]

synonym_properties = ['original_label', 
                      'cell_set_aligned_alias',
                      'cell_set_additional_aliases']
for o in out['nodes']:
    d = {}
    d['ID'] = o['cell_set_accession']
    d['Label'] = o['cell_set_label']
    d['PrefLabel'] = o['cell_set_preferred_alias']
    d['Entity Type'] = 'Cluster'
    d['Synonyms'] = '|'.join([o[prop] for prop in synonym_properties if o[prop]])
    d['Property Assertions'] = '|'.join([e[1] for e in out['edges'] if e[0] == d['ID']]) # There should only be one!
    dl.append(d)

robot_template = pd.DataFrame.from_records(dl)
print(robot_template[['ID','PrefLabel']][0:50])
print(robot_template[['ID','PrefLabel']][51:100])
print(robot_template[['ID','PrefLabel']][100:-1])
# Out:
#                  ID                PrefLabel
# 0                ID           skos:prefLabel
# 1    CS201908210_76
# 2    CS201908210_77                 Neuronal
# 3    CS201908210_78               Inhibitory
# 4    CS201908210_79             ADARB2 (CGE)
# 5    CS201908210_80               LAMP5/PAX6
# 6    CS201908210_81
# 7     CS201908210_1      Inh L1-2 PAX6 CDH12
# 8     CS201908210_2  Inh L1-2 PAX6 TNFAIP8L3
# 9    CS201908210_82
# 10    CS201908210_3        Inh L1 LAMP5 NMBR
# 11   CS201908210_83
# 12   CS201908210_84
# 13    CS201908210_4      Inh L1-4 LAMP5 LCP2
# 14    CS201908210_5       Inh L1-2 LAMP5 DBP
# 15    CS201908210_6       Inh L2-6 LAMP5 CA1
# 16   CS201908210_85                      VIP
# 17   CS201908210_86
# 18   CS201908210_87
# 19   CS201908210_88
# 20   CS201908210_89
# 21    CS201908210_7        Inh L1 SST CHRNA4
# 22    CS201908210_8     Inh L1-2 ADARB2 MC4R
# 23    CS201908210_9       Inh L1-2 SST BAGE2
# 24   CS201908210_90
# 25   CS201908210_10        Inh L1-3 VIP SYT6
# 26   CS201908210_91
# 27   CS201908210_11     Inh L1-2 VIP TSPAN12
# 28   CS201908210_12      Inh L1-4 VIP CHRNA6
# 29   CS201908210_92
# 30   CS201908210_13    Inh L1-3 VIP ADAMTSL1
# 31   CS201908210_14        Inh L1-4 VIP PENK
# 32   CS201908210_93
# 33   CS201908210_94
# 34   CS201908210_95
# 35   CS201908210_96
# 36   CS201908210_15        Inh L2-6 VIP QPCT
# 37   CS201908210_16    Inh L3-6 VIP HS3ST3A1
# 38   CS201908210_17      Inh L1-2 VIP PCDH20
# 39   CS201908210_97
# 40   CS201908210_18    Inh L2-5 VIP SERPINF1
# 41   CS201908210_19         Inh L2-5 VIP TYR
# 42   CS201908210_98
# 43   CS201908210_99
# 44  CS201908210_100
# 45  CS201908210_101
# 46   CS201908210_20       Inh L1-3 VIP CHRM2
# 47   CS201908210_21       Inh L2-4 VIP CBLN1
# 48   CS201908210_22     Inh L1-3 VIP CCDC184
# 49   CS201908210_23         Inh L1-3 VIP GGH
#                  ID              PrefLabel
# 51  CS201908210_103
# 52   CS201908210_24       Inh L1-2 VIP LBH
# 53   CS201908210_25     Inh L2-3 VIP CASC6
# 54  CS201908210_104
# 55   CS201908210_26    Inh L2-4 VIP SPAG17
# 56   CS201908210_27     Inh L1-4 VIP OPRM1
# 57  CS201908210_105             LHX6 (MGE)
# 58  CS201908210_106
# 59   CS201908210_28       Inh L3-6 SST NPY
# 60  CS201908210_107
# 61  CS201908210_108                    SST
# 62  CS201908210_109
# 63  CS201908210_110
# 64   CS201908210_29      Inh L3-6 SST HPGD
# 65  CS201908210_111
# 66  CS201908210_112
# 67  CS201908210_113
# 68   CS201908210_30    Inh L4-6 SST B3GAT2
# 69   CS201908210_31   Inh L5-6 SST KLHDC8A
# 70  CS201908210_114
# 71   CS201908210_32   Inh L5-6 SST NPM1P10
# 72   CS201908210_33    Inh L4-6 SST GXYLT2
# 73   CS201908210_34    Inh L4-5 SST STK32A
# 74  CS201908210_115
# 75  CS201908210_116
# 76   CS201908210_35     Inh L1-3 SST CALB1
# 77   CS201908210_36    Inh L3-5 SST ADGRG6
# 78   CS201908210_37      Inh L2-4 SST FRZB
# 79   CS201908210_38        Inh L5-6 SST TH
# 80  CS201908210_117                  PVALB
# 81   CS201908210_39    Inh L5-6 LHX6 GLP1R
# 82  CS201908210_118
# 83   CS201908210_40    Inh L5-6 PVALB LGR5
# 84  CS201908210_119
# 85  CS201908210_120
# 86   CS201908210_41    Inh L4-5 PVALB MEPE
# 87  CS201908210_121
# 88   CS201908210_42   Inh L2-4 PVALB WFDC2
# 89   CS201908210_43   Inh L4-6 PVALB SULF1
# 90   CS201908210_44  Inh L5-6 SST MIR548F2
# 91   CS201908210_45  Inh L2-5 PVALB SCUBE3
# 92  CS201908210_122             Excitatory
# 93  CS201908210_123
# 94  CS201908210_124
# 95  CS201908210_125
# 96  CS201908210_126
# 97  CS201908210_127                   L2/3
# 98  CS201908210_128
# 99   CS201908210_46       Exc L2 LAMP5 LTK
#                   ID                 PrefLabel
# 100   CS201908210_47  Exc L2-4 LINC00507 GLP2R
# 101   CS201908210_48  Exc L2-3 LINC00507 FREM3
# 102   CS201908210_49     Exc L5-6 THEMIS C1QL3
# 103  CS201908210_129                      RORB
# 104  CS201908210_130                        L4
# 105   CS201908210_50     Exc L3-4 RORB CARM1P1
# 106  CS201908210_131
# 107   CS201908210_51        Exc L3-5 RORB ESR1
# 108  CS201908210_132
# 109   CS201908210_52     Exc L3-5 RORB COL22A1
# 110  CS201908210_133
# 111   CS201908210_53     Exc L3-5 RORB FILIP1L
# 112   CS201908210_54      Exc L3-5 RORB TWIST2
# 113  CS201908210_134
# 114  CS201908210_135
# 115   CS201908210_55      Exc L4-5 RORB FOLH1B
# 116  CS201908210_136
# 117   CS201908210_56      Exc L4-6 RORB SEMA3E
# 118   CS201908210_57       Exc L4-5 RORB DAPK2
# 119  CS201908210_137
# 120   CS201908210_58       Exc L5-6 RORB TTC12
# 121   CS201908210_59         Exc L4-6 RORB C1R
# 122   CS201908210_60      Exc L4-5 FEZF2 SCN4B
# 123  CS201908210_138                        L6
# 124   CS201908210_61   Exc L5-6 THEMIS DCSTAMP
# 125  CS201908210_139
# 126   CS201908210_62    Exc L5-6 THEMIS CRABP1
# 127   CS201908210_63     Exc L5-6 THEMIS FGF10
# 128  CS201908210_140                     FEZF2
# 129   CS201908210_64       Exc L4-6 FEZF2 IL26
# 130  CS201908210_141                        L6
# 131   CS201908210_65        Exc L5-6 FEZF2 ABO
# 132  CS201908210_142
# 133  CS201908210_143
# 134  CS201908210_144
# 135   CS201908210_66       Exc L6 FEZF2 SCUBE1
# 136   CS201908210_67       Exc L5-6 FEZF2 IL15
# 137   CS201908210_68        Exc L6 FEZF2 OR2T8
# 138   CS201908210_69   Exc L5-6 FEZF2 EFTUD1P1
# 139  CS201908210_145              Non-neuronal
# 140  CS201908210_146
# 141  CS201908210_147
# 142  CS201908210_148
# 143   CS201908210_70           OPC L1-6 PDGFRA
# 144  CS201908210_149
# 145   CS201908210_71  Astro L1-6 FGFR3 SLC14A1
# 146   CS201908210_72     Astro L1-2 FGFR3 GFAP
# 147   CS201908210_73         Oligo L1-6 OPALIN
# 148   CS201908210_74         Endo L2-6 NOSTRIN
